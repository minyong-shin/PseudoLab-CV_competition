# %%
import os
import pandas as pd

# %%
first_path = './lanmark_dataset/train'

# %%
total_class = []
for i in os.listdir(first_path):
    if 'DS' in i:
        pass
    else:
        second_path = os.path.join(first_path,i)
        
        for j in os.listdir(second_path):
            if 'DS' in j:
                pass
            else:
                total_class += os.listdir(os.path.join(second_path,j))

# %%
len(total_class)
# Out:
# 88102

# %%
df = pd.DataFrame()
df['id'] = total_class

# %%
df[df['id'] == '우림시장_096.JPG']
# Out:
#                        id
# 28587  우림시장_096.JPG

# %%
df = pd.
total_class
# Out:
# ['상무조각공원',
#  '상록도서관',
#  '호가정',
#  '양동시장',
#  '유애서원',
#  '남구 청소년도서관',
#  '홀리데이인 광주호텔',
#  '무양서원',
#  '광주학생독립운동기념공원(광주학생독립운동역사관, 광주학생독립운동기념탑 포함)',
#  '광주 남구 청소년 수련관(문화정보 도서관, 문화원, 남구 생활문화센터 포함)',
#  '역사문화공원',
#  '김대중컨벤션센터',
#  '이야기꽃도서관',
#  '광산구 쌍암공원',
#  '광주광역시 서구청',
#  '양씨삼강문',
#  '취병조형유허비',
#  '무등경기장 야구장',
#  '양산호수공원',
#  '김대중컨벤션센터역',
#  '광주광역시 남구청',
#  '운남동 근린공원',
#  '올림픽대교',
#  '별마당 도서관',
#  '종로성당',
#  '하늘공원',
#  '구서울대학교본관',
#  '중랑구립정보도서관',
#  '동호대교',
#  '서경대학교',
#  '광화문',
#  '동대문구청',
#  '성신여자대학교',
#  '강북삼성병원',
#  '정릉',
#  '경리단길',
#  '독립문',
# ...

# %%
batch_time = AverageMeter()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-18f0788086d0> in <module>
# ----> 1 batch_time = AverageMeter()
#
# NameError: name 'AverageMeter' is not defined

# %%
import time
